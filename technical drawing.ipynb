# %%
import sys
sys.path.append("/Users/ahmetbugrafazlioglu/Desktop/TechnicalDrawingPython-main")
import numpy as np
import math
from mpl_toolkits import mplot3d
from technicaldrawpy import Transformations,Sahne,Camera,Vertex,Edge,Surface,LinearObject,Cube,Sahnecams,Utilities

# %%
sahne=Sahnecams.Sahnecams(35,6,15,"Ana Sahne\n",1)
sahne.copdistancelimit=10
mycam1=Camera.Camera(90,8,-90,sahne,"Kamera\n",[-2,2])
mycam1.set_copfocalsxyz([-1000000,-1000000,-6]) 
mycam1.set_generateviewbools(False,False,True,False,False,False)
sahne.addcamera(mycam1)
mycube=Cube.Cube(4,4,4,sahne1,"Küp")
mycube.rotate_y(math.pi/9)
mycube.translate_xyz(0,0,4)
sahne.addobj(mycube)
sahne.calculate_positions()
sahne.show()
